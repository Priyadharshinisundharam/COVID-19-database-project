# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
daily = pd.read_csv(r"C:\Users\dhars\OneDrive\Desktop\Covid 19 project\Coronavirus_cases_daily_update.csv")
codebook = pd.read_csv(r"C:\Users\dhars\OneDrive\Desktop\Covid 19 project\owid_covid_codebook.csv")

# %%
daily.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-05          0.0        0.0
# 1      AFG      Asia  Afghanistan  2020-01-06          0.0        0.0
# 2      AFG      Asia  Afghanistan  2020-01-07          0.0        0.0
# 3      AFG      Asia  Afghanistan  2020-01-08          0.0        0.0
# 4      AFG      Asia  Afghanistan  2020-01-09          0.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           0.0         0.0                  NaN  ...
# 1                 NaN           0.0         0.0                  NaN  ...
# 2                 NaN           0.0         0.0                  NaN  ...
# 3                 NaN           0.0         0.0                  NaN  ...
# 4                 NaN           0.0         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
daily.tail()
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 429430      ZWE    Africa  Zimbabwe  2024-07-31     266386.0        0.0
# 429431      ZWE    Africa  Zimbabwe  2024-08-01     266386.0        0.0
# 429432      ZWE    Africa  Zimbabwe  2024-08-02     266386.0        0.0
# 429433      ZWE    Africa  Zimbabwe  2024-08-03     266386.0        0.0
# 429434      ZWE    Africa  Zimbabwe  2024-08-04     266386.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 429430                 0.0        5740.0         0.0                  0.0
# 429431                 0.0        5740.0         0.0                  0.0
# 429432                 0.0        5740.0         0.0                  0.0
# 429433                 0.0        5740.0         0.0                  0.0
# 429434                 0.0        5740.0         0.0                  0.0
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 429435 entries, 0 to 429434
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    429435 non-null  object
#  1   continent                                   402910 non-null  object
#  2   location                                    429435 non-null  object
#  3   date                                        429435 non-null  object
#  4   total_cases                                 411804 non-null  float64
#  5   new_cases                                   410159 non-null  float64
#  6   new_cases_smoothed                          408929 non-null  float64
#  7   total_deaths                                411804 non-null  float64
#  8   new_deaths                                  410608 non-null  float64
# ...

# %%
daily.shape
# Out:
# (429435, 67)

# %%
daily.describe
# Out:
# <bound method NDFrame.describe of        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-01-05          0.0        0.0
# 1           AFG      Asia  Afghanistan  2020-01-06          0.0        0.0
# 2           AFG      Asia  Afghanistan  2020-01-07          0.0        0.0
# 3           AFG      Asia  Afghanistan  2020-01-08          0.0        0.0
# 4           AFG      Asia  Afghanistan  2020-01-09          0.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 429430      ZWE    Africa     Zimbabwe  2024-07-31     266386.0        0.0
# 429431      ZWE    Africa     Zimbabwe  2024-08-01     266386.0        0.0
# 429432      ZWE    Africa     Zimbabwe  2024-08-02     266386.0        0.0
# 429433      ZWE    Africa     Zimbabwe  2024-08-03     266386.0        0.0
# 429434      ZWE    Africa     Zimbabwe  2024-08-04     266386.0        0.0
#
# ...

# %%
daily.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
daily.index
# Out:
# RangeIndex(start=0, stop=429435, step=1)

# %%
daily.isna().sum()
# Out:
# iso_code                                        0
# continent                                   26525
# location                                        0
# date                                            0
# total_cases                                 17631
#                                             ...
# population                                      0
# excess_mortality_cumulative_absolute       416024
# excess_mortality_cumulative                416024
# excess_mortality                           416024
# excess_mortality_cumulative_per_million    416024
# Length: 67, dtype: int64

# %%
daily.count()
# Out:
# iso_code                                   429435
# continent                                  402910
# location                                   429435
# date                                       429435
# total_cases                                411804
#                                             ...
# population                                 429435
# excess_mortality_cumulative_absolute        13411
# excess_mortality_cumulative                 13411
# excess_mortality                            13411
# excess_mortality_cumulative_per_million     13411
# Length: 67, dtype: int64

# %%
#replace missing values with 0
daily.fillna(0, inplace=True)

# %%
daily.isna().sum()
# Out:
# iso_code                                   0
# continent                                  0
# location                                   0
# date                                       0
# total_cases                                0
#                                           ..
# population                                 0
# excess_mortality_cumulative_absolute       0
# excess_mortality_cumulative                0
# excess_mortality                           0
# excess_mortality_cumulative_per_million    0
# Length: 67, dtype: int64

# %%
#drop columns that are not needed
daily.drop(columns=['iso_code',
                    'new_cases_smoothed',
                    'new_deaths_smoothed',
                    'total_cases_per_million',
                    'new_cases_per_million',
                    'new_cases_smoothed_per_million',
                    'total_deaths_per_million',
                    'new_deaths_per_million',
                    'new_deaths_smoothed_per_million',
                    'icu_patients_per_million',
                    'hosp_patients_per_million',
                    'weekly_icu_admissions_per_million',
                    'weekly_hosp_admissions_per_million',
                    'new_tests_smoothed',
                    'new_tests_smoothed_per_thousand',
                    'total_tests_per_thousand',
                    'new_vaccinations_smoothed',
                    'new_vaccinations_smoothed_per_million',
                    'total_vaccinations_per_hundred',
                    'people_vaccinated_per_hundred',
                    'people_fully_vaccinated_per_hundred',
                    'total_boosters_per_hundred',
                    'hospital_beds_per_thousand',
                    'excess_mortality_cumulative_per_million',
                    'new_people_vaccinated_smoothed',
                    'new_people_vaccinated_smoothed_per_hundred'], inplace=True)

# %%
daily.columns
# Out:
# Index(['continent', 'location', 'date', 'total_cases', 'new_cases',
#        'total_deaths', 'new_deaths', 'reproduction_rate', 'icu_patients',
#        'hosp_patients', 'weekly_icu_admissions', 'weekly_hosp_admissions',
#        'total_tests', 'new_tests', 'new_tests_per_thousand', 'positive_rate',
#        'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'new_vaccinations', 'stringency_index', 'population_density',
#        'median_age', 'aged_65_older', 'aged_70_older', 'gdp_per_capita',
#        'extreme_poverty', 'cardiovasc_death_rate', 'diabetes_prevalence',
#        'female_smokers', 'male_smokers', 'handwashing_facilities',
#        'life_expectancy', 'human_development_index', 'population',
#        'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative',
#        'excess_mortality'],
#       dtype='object')

# %%
daily.shape
# Out:
# (429435, 41)

# %%
codebook.head()
# Out:
#         column                                          source  \
# 0     iso_code  International Organization for Standardization
# 1    continent                               Our World in Data
# 2     location                               Our World in Data
# 3         date                               Our World in Data
# 4  total_cases                   COVID-19 Dashboard by the WHO
#
#           category                                        description
# 0           Others  ISO 3166-1 alpha-3 – three-letter country code...
# 1           Others             Continent of the geographical location
# 2           Others                              Geographical location
# 3           Others                                Date of observation
# 4  Confirmed cases  Total confirmed cases of COVID-19. Counts can ...

# %%
codebook.tail()
# Out:
#                                      column  \
# 62                  human_development_index
# 63                         excess_mortality
# 64              excess_mortality_cumulative
# 65     excess_mortality_cumulative_absolute
# 66  excess_mortality_cumulative_per_million
#
#                                                source          category  \
# 62        United Nations Development Programme (UNDP)            Others
# 63  Human Mortality Database (2021), World Mortali...  Excess mortality
# 64  Human Mortality Database (2021), World Mortali...  Excess mortality
# 65  Human Mortality Database (2021), World Mortali...  Excess mortality
# 66  Human Mortality Database (2021), World Mortali...  Excess mortality
#
#                                           description
# 62  A composite index measuring average achievemen...
# 63  Percentage difference between the reported num...
# 64  Percentage difference between the cumulative n...
# ...

# %%
codebook.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   column       67 non-null     object
#  1   source       67 non-null     object
#  2   category     67 non-null     object
#  3   description  67 non-null     object
# dtypes: object(4)
# memory usage: 2.2+ KB

# %%
codebook.shape
# Out:
# (67, 4)

# %%
codebook.columns
# Out:
# Index(['column', 'source', 'category', 'description'], dtype='object')

# %%
codebook.index
# Out:
# RangeIndex(start=0, stop=67, step=1)

# %%
codebook.isna().sum()
# Out:
# column         0
# source         0
# category       0
# description    0
# dtype: int64

# %%
codebook.describe
# Out:
# <bound method NDFrame.describe of                                      column  \
# 0                                  iso_code
# 1                                 continent
# 2                                  location
# 3                                      date
# 4                               total_cases
# ..                                      ...
# 62                  human_development_index
# 63                         excess_mortality
# 64              excess_mortality_cumulative
# 65     excess_mortality_cumulative_absolute
# 66  excess_mortality_cumulative_per_million
#
#                                                source          category  \
# 0      International Organization for Standardization            Others
# 1                                   Our World in Data            Others
# 2                                   Our World in Data            Others
# 3                                   Our World in Data            Others
# ...

# %%
codebook.count()
# Out:
# column         67
# source         67
# category       67
# description    67
# dtype: int64

# %%
#count of cases on the year 2020
count_of_cases_2020 = daily[daily['date'].str.contains('2020')].count()
print("Count of cases on the year 2020:")
print(count_of_cases_2020)
# Out:
# Count of cases on the year 2020:
# continent                               90982
# location                                90982
# date                                    90982
# total_cases                             90982
# new_cases                               90982
# total_deaths                            90982
# new_deaths                              90982
# reproduction_rate                       90982
# icu_patients                            90982
# hosp_patients                           90982
# weekly_icu_admissions                   90982
# weekly_hosp_admissions                  90982
# total_tests                             90982
# new_tests                               90982
# new_tests_per_thousand                  90982
# positive_rate                           90982
# tests_per_case                          90982
# tests_units                             90982
# total_vaccinations                      90982
# people_vaccinated                       90982
# ...

# %%
#count of cases on the year 2021
count_of_cases_2021 = daily[daily['date'].str.contains('2021')].count()
print("Count of cases on the year 2021:")
print(count_of_cases_2021)
# Out:
# Count of cases on the year 2021:
# continent                               95088
# location                                95088
# date                                    95088
# total_cases                             95088
# new_cases                               95088
# total_deaths                            95088
# new_deaths                              95088
# reproduction_rate                       95088
# icu_patients                            95088
# hosp_patients                           95088
# weekly_icu_admissions                   95088
# weekly_hosp_admissions                  95088
# total_tests                             95088
# new_tests                               95088
# new_tests_per_thousand                  95088
# positive_rate                           95088
# tests_per_case                          95088
# tests_units                             95088
# total_vaccinations                      95088
# people_vaccinated                       95088
# ...

# %%
#count of cases on the year 2022
count_of_cases_2022 = daily[daily['date'].str.contains('2022')].count()
print("Count of cases on the year 2022:")
print(count_of_cases_2022)
# Out:
# Count of cases on the year 2022:
# continent                               94932
# location                                94932
# date                                    94932
# total_cases                             94932
# new_cases                               94932
# total_deaths                            94932
# new_deaths                              94932
# reproduction_rate                       94932
# icu_patients                            94932
# hosp_patients                           94932
# weekly_icu_admissions                   94932
# weekly_hosp_admissions                  94932
# total_tests                             94932
# new_tests                               94932
# new_tests_per_thousand                  94932
# positive_rate                           94932
# tests_per_case                          94932
# tests_units                             94932
# total_vaccinations                      94932
# people_vaccinated                       94932
# ...

# %%
#count of cases on the year 2023
count_of_cases_2023 = daily[daily['date'].str.contains('2023')].count()
print("Count of cases on the year 2023:")
print(count_of_cases_2023)
# Out:
# Count of cases on the year 2023:
# continent                               93831
# location                                93831
# date                                    93831
# total_cases                             93831
# new_cases                               93831
# total_deaths                            93831
# new_deaths                              93831
# reproduction_rate                       93831
# icu_patients                            93831
# hosp_patients                           93831
# weekly_icu_admissions                   93831
# weekly_hosp_admissions                  93831
# total_tests                             93831
# new_tests                               93831
# new_tests_per_thousand                  93831
# positive_rate                           93831
# tests_per_case                          93831
# tests_units                             93831
# total_vaccinations                      93831
# people_vaccinated                       93831
# ...

# %%
#count of cases on the year 2024
count_of_cases_2024 = daily[daily['date'].str.contains('2024')].count()
print("Count of cases on the year 2024:")
print(count_of_cases_2024)
# Out:
# Count of cases on the year 2024:
# continent                               54602
# location                                54602
# date                                    54602
# total_cases                             54602
# new_cases                               54602
# total_deaths                            54602
# new_deaths                              54602
# reproduction_rate                       54602
# icu_patients                            54602
# hosp_patients                           54602
# weekly_icu_admissions                   54602
# weekly_hosp_admissions                  54602
# total_tests                             54602
# new_tests                               54602
# new_tests_per_thousand                  54602
# positive_rate                           54602
# tests_per_case                          54602
# tests_units                             54602
# total_vaccinations                      54602
# people_vaccinated                       54602
# ...

# %%
#save the cleaned data to a new CSV file
daily.to_csv(r"C:\Users\dhars\OneDrive\Desktop\Covid 19 project\cleaned_coronavirus_cases_daily_update.csv", index=False)
codebook.to_csv(r"C:\Users\dhars\OneDrive\Desktop\Covid 19 project\cleaned_owid_covid_codebook.csv", index=False)
print("Cleaned data saved successfully.")
# Out:
# Cleaned data saved successfully.
